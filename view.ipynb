# %%
import pandas as pd;

weather_df = pd.read_csv('./final_weather_data/2000_weather_data.csv', low_memory=False)
stations_df = pd.read_csv('./station-outputs/cleaned-station-data.csv', low_memory=False)
processed_df = pd.read_csv('./weather-outputs/2000_processed.csv', low_memory=False)

# %%
usa_state_codes = [
    'AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'FL', 'GA',
    'HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD',
    'MA', 'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ',
    'NM', 'NY', 'NC', 'ND', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC',
    'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY',
    'DC' 
]

# %%
# weather_df.loc[weather_df['state'] == 'MN']
stations_df.loc[stations_df['state'] == 'CA']
# Out:
#         station_id state  latitude  longitude  elevation
# 3773   US1CAAL0001    CA   37.8123  -122.2160      113.4
# 3774   US1CAAL0002    CA   37.7075  -122.0687       87.5
# 3775   US1CAAL0003    CA   37.7169  -122.0585      163.4
# 3776   US1CAAL0004    CA   37.6483  -121.8745      107.0
# 3777   US1CAAL0006    CA   37.8319  -122.2503       58.2
# ...            ...   ...       ...        ...        ...
# 73929  USW00093241    CA   38.3775  -121.9586       31.7
# 73930  USW00093242    CA   36.9850  -120.1106       76.5
# 73931  USW00093243    CA   37.2381  -120.8825       23.8
# 73932  USW00093245    CA   38.3208  -123.0747       19.2
# 74140  USW00094299    CA   41.4836  -120.5614     1335.9
#
# [3138 rows x 5 columns]
